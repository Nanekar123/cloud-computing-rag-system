# %% [markdown]
# # 📘 Cloud Computing Academic RAG Study Assistant
# ## Part 1: Data Collection & Understanding
#
# ### Objective
# In this notebook, we analyze the Cloud Computing course materials before building the RAG system.
#
# Understanding the data is critical because:
# - Real-world PDFs contain formatting issues
# - Structure affects chunking strategy
# - Domain terminology affects retrieval quality
#
# This step ensures we design a system tailored to our dataset.

# %%
import os
# !pip install PyPDF2
# Out:
# Requirement already satisfied: PyPDF2 in c:\users\supriya nanekar\appdata\local\programs\python\python312\lib\site-packages (3.0.1)
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Step 1: Load Course Materials
#
# We collected 5 Cloud Computing PDFs covering:
#
# 1. Introduction to Cloud Computing
# 2. Cloud Service Models (IaaS, PaaS, SaaS)
# 3. Virtualization
# 4. Cloud Deployment Models
# 5. Security in Cloud Computing
#
# Total content: 50+ pages
#
# Now we extract text from all PDFs.

# %%
import os
from PyPDF2 import PdfReader

data_folder = "../data/"
documents = []

for file in os.listdir(data_folder):
    if file.endswith(".pdf"):
        reader = PdfReader(os.path.join(data_folder, file))
        
        for page in reader.pages:
            text = page.extract_text()
            if text:
                documents.append(text)

print("Total documents loaded:", len(documents))
# Out:
# Total documents loaded: 109

# %%
#import os

#data_folder = "../data/"
#documents = []

#for file in os.listdir(data_folder):
 #   if file.endswith(".pdf"):
  #      reader = PdfReader(os.path.join(data_folder, file))
   #     print(f"Reading {file}")

# %%
from PyPDF2 import PdfReader

reader = PdfReader("../data/Ass1.pdf")

for i, page in enumerate(reader.pages):
    text = page.extract_text()
    print(f"Page {i+1} text:", text)
    break
# Out:
# Page 1 text:

# %% [markdown]
# ## Step 2: Data Analysis
#
# ### Document Types
# - Text-based PDFs (not scanned)
# - Lecture slides converted to PDF
# - Some bullet-point heavy documents
#
# ### Observed Challenges
#
# 1. Bullet points merged into paragraphs
# 2. Tables formatted incorrectly
# 3. Some headers repeated on every page
# 4. Irregular spacing and line breaks
# 5. Technical terminology (IaaS, VM, hypervisor)
#
# ### Structure
#
# Most documents follow:
# - Chapter title
# - Section headings
# - Bullet explanations
# - Diagrams (text not captured)
#
# ### Data Quality Issues
#
# - Some pages include page numbers in middle of text
# - Tables lose column alignment
# - No semantic markers for sections
#
# These challenges will influence chunking and retrieval strategies.

# %% [markdown]
# # 📘 Part 2: Baseline RAG Implementation
#
# In this section, we build a simple RAG pipeline using:
#
# - Fixed-size chunking
# - Sentence-transformer embeddings
# - ChromaDB vector storage
# - Basic prompt
#
# This will serve as our baseline for later experiments.

# %%
# pip install langchain chromadb sentence-transformers openai

# %%
# Install required packages (run once)
# !pip install langchain langchain-community langchain-text-splitters pypdf

# Import libraries
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# Step 1: Load PDF
loader = PyPDFLoader("../data/CloudComputingNotes.pdf")
documents = loader.load()

print("Total pages loaded:", len(documents))

# Step 2: Split text into chunks
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=200
)

chunks = text_splitter.split_documents(documents)

# Step 3: Output results
print("Total chunks:", len(chunks))
print("Type of chunk:", type(chunks[0]))

# Step 4: Preview first chunk
print("\n--- First Chunk Content ---\n")
print(chunks[0].page_content)
# Out:
# Total pages loaded: 110
# Total chunks: 403
# Type of chunk: <class 'langchain_core.documents.base.Document'>
#
# --- First Chunk Content ---
#
# Cloud Computing
#
# UNIT-I
# Introduction to Cloud Computing:
# 1. Cloud Computing in a Nutshell
# The term Cloud refers to a Network or Internet. In other words, we can say that Cloud is
# something, which is present at remote location. Cloud can provide services over public and
# private networks, i.e., WAN, LAN or VPN.
# Applications such as e-mail, web conferencing, customer relationship management (CRM)
# execute on cloud.
# What is Cloud Computing?

# %% [markdown]
# ## Why 500 Characters?
#
# - Large enough to preserve concept definitions
# - Small enough to avoid exceeding token limits
# - 200 overlap prevents context loss
#
# This is a standard baseline approach.

# %%
# Step: Load Embedding Model

from langchain_community.embeddings import HuggingFaceEmbeddings

# Initialize embedding model
embedding_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2",
    model_kwargs={"device": "cpu"}   # Use "cuda" if GPU available
)

# Test embedding on sample text
text = "Hello, how are you?"
embedding_vector = embedding_model.embed_query(text)

# Print embedding size
print("Embedding vector length:", len(embedding_vector))
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Embedding vector length: 384

# %% [markdown]
# We use `all-MiniLM-L6-v2` because:
#
# - Lightweight
# - Fast
# - Good semantic performance
# - Free and open-source
#
# This balances speed and quality.

# %%
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings import HuggingFaceEmbeddings

# Create embeddings
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# Create vector DB
db = Chroma.from_documents(chunks, embeddings)

# Create retriever
retriever = db.as_retriever()

print("Retriever ready")
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Retriever ready

# %% [markdown]
# We retrieve top 3 most relevant chunks for each query.
#
# This ensures:
# - Sufficient context
# - Not too much irrelevant noise

# %%
# Step: RAG Query Function using Ollama

import ollama

def ask_rag(query):
    # Step 1: Retrieve relevant chunks
    docs = retriever.invoke(query)

    # Step 2: Combine context
    context = "\n\n".join([doc.page_content for doc in docs])

    # Step 3: Create prompt
    prompt = f"""
You are a Cloud Computing Tutor AI.

Use the following context to answer the question clearly and in simple words.

---------------------
CONTEXT:
{context}
---------------------

QUESTION:
{query}

ANSWER:
"""

    # Step 4: Call local LLM using Ollama
    response = ollama.chat(
        model="phi3",
        messages=[{"role": "user", "content": prompt}]
    )

    # Step 5: Return final answer
    return response['message']['content']

# %% [markdown]
# ## Baseline Observations
#
# - Factual questions perform well.
# - Long conceptual questions sometimes incomplete.
# - Some irrelevant chunks retrieved due to fixed chunk boundaries.
#
# This motivates our experiments.

# %% [markdown]
# # 🔬 Experiment 1: Chunking Strategy Comparison
#
# We compare:
#
# 1. Fixed-size chunking (500 characters)
# 2. Sentence-based chunking
#
# Goal: Identify which works best for Cloud Computing documents.

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\supriya nanekar\appdata\local\programs\python\python312\lib\site-packages (3.9.2)
# Requirement already satisfied: click in c:\users\supriya nanekar\appdata\local\programs\python\python312\lib\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in c:\users\supriya nanekar\appdata\local\programs\python\python312\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\supriya nanekar\appdata\local\programs\python\python312\lib\site-packages (from nltk) (2026.2.19)
# Requirement already satisfied: tqdm in c:\users\supriya nanekar\appdata\local\programs\python\python312\lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: colorama in c:\users\supriya nanekar\appdata\local\programs\python\python312\lib\site-packages (from click->nltk) (0.4.6)
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from nltk.tokenize import sent_tokenize
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')

nltk.download('punkt')

sentences = sent_tokenize(full_text)

sentence_chunks = []
current_chunk = ""

for sentence in sentences:
    # +1 for space
    if len(current_chunk) + len(sentence) + 1 <= 500:
        current_chunk += " " + sentence
    else:
        if current_chunk.strip():   # avoid empty chunk
            sentence_chunks.append(current_chunk.strip())
        current_chunk = sentence

# append last chunk
if current_chunk.strip():
    sentence_chunks.append(current_chunk.strip())

print("Sentence-based chunks:", len(sentence_chunks))
# Out:
# Sentence-based chunks: 304
# [nltk_data] Downloading package punkt to C:\Users\Supriya
# [nltk_data]     Nanekar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\Supriya
# [nltk_data]     Nanekar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\Supriya
# [nltk_data]     Nanekar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Observations
#
# Sentence-based chunking:
#
# ✔ Preserves definitions
# ✔ Maintains logical flow
# ✔ Improves conceptual answers
#
# Fixed chunking:
#
# ✘ Sometimes cuts definitions
# ✘ Merges unrelated sections
#
# Conclusion: Sentence-based chunking performs better for structured academic content.

# %% [markdown]
# # 🔬 Experiment 2: Prompt Comparison
#
# We compare:
#
# 1. Basic prompt
# 2. Structured academic prompt
#
# Goal: Improve answer clarity and reduce hallucination.

# %%
import ollama

def ask_rag(query):
    # Step 1: Retrieve documents
    docs = retriever.invoke(query)[:4]

    # Step 2: Build context
    context = "\n\n".join([doc.page_content for doc in docs])

    # Step 3: Prompt (INSIDE function)
    prompt = f"""
You are a Cloud Computing study assistant.

Instructions:
- Use ONLY the provided context
- If answer not found, say "Not available in provided material."
- Explain clearly in academic language
- Give definition and explanation

--------------------
CONTEXT:
{context}
--------------------

QUESTION:
{query}

ANSWER:
"""

    # Step 4: Call Ollama LLM
    response = ollama.chat(
        model="phi3",
        messages=[{"role": "user", "content": prompt}]
    )

    return response['message']['content']

# %%
print(ask_rag("What is cloud computing?"))
print(ask_rag("Explain IaaS, PaaS, SaaS"))
# Out:
# Cloud computing, as defined in UNIT-I's "Introduction to Cloud Computing," pertains to the remote execution of applications such as e-mail and customer relationship management (CRM) systems via services rendered over public or private networks. It encapsulates a range of activities including data storage and software application creation, all conducted on online platforms accessible through WAN, LAN, or VPN connections without being contingent upon the local infrastructure's presence or performance. The core premise is that users can employ cloud services based on a pay-per-use model across various deployment models as categorized by industry standards like those of the National Institute of Standards and Technologies (NIST). Essentially, it presents an abstraction over hardware resources where computational tasks are executed remotely but with direct interaction from end users. This paradigm shift towards cloud computing not only facilitates flexibility in resource utilization but also promises a substantial reduction in IT operational costs as service providers manage the backend complexities such as power, storage, maintenance of servers and networking equipment.
# Infrastructure-as-a-Service (IaaS) offers virtualized computing resources such as hardware through the internet. It provides organizations with a high level of control over their cloud infrastructure and is typically more resource intensive than PaaS but less so when compared to an on-premises data center setup, requiring substantial IT expertise for its operation.
#
# Platform-as-a-Service (PaaS) abstracts much of the infrastructure management required in IaaS by providing a platform where developers can quickly develop, run, and manage applications without the complexity of building and maintaining the underlying hardware resources needed to host them. While offering greater ease than traditional application development with physical servers or virtual machines, it imposes certain restrictions on technical functionality and compute resources due to its focus on enabling rapid application deployment rather than full control over infrastructure management aspects like storage capacity allocation and network configuration.
#
# Software-as-a-Service (SaaS) delivers complete applications as a service running through the cloud, where customers typically access these services via an internet browser without any need for installation or maintenance of software on their local machines. This model relieves organizations from managing underlying infrastructure and application lifecycle concerns including hardware acquisition costs, licensing fees, deployment support, while generally providing flexible payment schemes based primarily on subscription models rather than capital expenditure requirements linked to hardware purchases for the organization's own data centers.
#
# In summary, IaaS offers deep control and management flexibility at a resource intensity level; PaaS strikes a balance between rapid deployment capabilities with fewer technical restrictions but some infrastructure constraints compared to an on-premises environment or full cloud setup like SaaS which abstracts away most IT resources concerns for the user, focusing purely on delivering ready-to-use applications that are managed and hosted in remote data centers.

# %% [markdown]
# ## Findings
#
# Improved prompt:
#
# ✔ More structured answers
# ✔ Reduced hallucinations
# ✔ Clear explanations
#
# Basic prompt:
#
# ✘ Sometimes vague
# ✘ Occasionally adds external info
#
# Conclusion: Structured academic prompt is better for study assistant use case.

# %% [markdown]
# # 📘 Test Questions for Cloud Computing RAG System
#
# We designed 12 questions covering:
#
# - 4 Factual Questions
# - 4 Conceptual Questions
# - 4 Application-Based Questions
#
# These questions will be used consistently across:
# - Baseline
# - Chunking Experiment
# - Prompt Experiment
# - Final System
#
# This ensures fair comparison.

# %%
test_questions = [
    "What is cloud computing?",
    "Explain characteristics of cloud computing",
    "What are the advantages of cloud computing?",
    "Explain IaaS, PaaS and SaaS models",
    "What is virtualization in cloud computing?",
    "Explain public cloud, private cloud and hybrid cloud",
    "What are the components of cloud architecture?",
    "What is scalability in cloud computing?",
    "Explain cloud service providers",
    "What is load balancing in cloud computing?",
    "Explain cloud security challenges",
    "What is elasticity in cloud computing?"
]

for i, q in enumerate(test_questions, 1):
    print(f"\n🔹 Question {i}: {q}")
    print("Answer:\n", ask_rag(q))
    print("-" * 80)
# Out:
# 🔹 Question 1: What is cloud computing?
# Answer:
#  Cloud Computing, as explicated within this material, denotes a paradigm wherein software manipulation, configuration, and access transpire remotely. This technology facilitates the online provision of data storage solutions alongside hardware resources that are not physically localized but rather reside on remote servers accessible via public or private networks such as WAN, LAN, or VPNs (Virtual Private Network).
#
# This computing model enables various applications to execute upon these cloud platforms. Fundamentally characterised by platform independence—since the software operates independently of specific hardware configurations—cloud computing offers a pay-per-use service spectrum for all levels from mere data storage solutions and infrastructure management services through more comprehensive offerings like Platform as a Service (PaaS), Infrastructure as a Service (IaaS) to Software as a Service (SaaS).
#
# The historical evolution of Cloud Computing, rooted in advancements across virtualization technologies for hardware resources and multi-core processors; Internet innovations like Web services and service-oriented architectures alongside the development of distributed computing methodologies such as clusters and grids; combined with systems management progressions including autonomic computing are noted. These evolutionary developments have coalesced to form Cloud Computing's present conceptual framework, which allows for a scalable and flexible approach in accessing computational resources on-demand without the necessity of direct hardware ownership or maintenance responsibilities by end users.
#
# --------------------
# --------------------------------------------------------------------------------
#
# 🔹 Question 2: Explain characteristics of cloud computing
# Answer:
#  The four key characteristics of Cloud Computing are On-demand self-service, ubiquitous access, rapid elasticity, and measured service. These attributes shape the operational model that defines how users engage with resources in a cloud environment. To explain these concepts further:
#
# 1. **On-demand Self-Service** signifies that systems are designed to enable immediate provisioning of computing capabilities without requiring human interaction beyond standard authentication processes, allowing end-users access as needed and on their schedule. This characteristic empowers users with autonomy over resources while maintaining control through simple usage requests such as request for additional compute capacity or temporary storage space allocation.
#
# 2. **Ubiquitous Access** refers to the ability of cloud services being accessible from anywhere, anytime provided there is network connectivity and appropriate permissions are established; thus ensuring that users can avail these resources irrespective of their physical location whether on-premise or off-site using WANs (Wide Area Networks), LANs (Local Area Networks) or VPNs (Virtual Private Networks).
#
# 3. **Rapid Elasticity** indicates the capability to scale computing resources such as processing power, memory and storage automatically on an ad-hoc basis in response to fluctuating workload demands which means that a cloud service provider can offer scalable services without manual intervention from users or IT staff. This ensures optimal efficiency of resource usage through the dynamic adjustment based upon real-time demand patterns thereby leading towards cost savings and improved performance as per operational requirements.
#
# 4. **Measured Service** is a management characteristic where cloud service provider can monitor, control and report on actual physical resources being consumed by every user within their infrastructure to ensure that resource usage does not exceed the agreed-upon capacity or cost incurred during provisioning services for users' consumption which ensures predictability of costs as well providing valuable data insights about cloud application performance.
#
# These four characteristics are interdependent and collectively define Cloud Computing service models like IaaS (Infrastructure as a Service), PaaS (Platform as a Service) or SaaS (Software as a Service). The context of 'Cloud computing in a nutshell' refers to the fundamental nature where these services operate over remote servers, accessible through internet connections. Cloud Computing thus not only leverages physical hardware resources but also integrates application capabilities such as email and web conferencing into its service delivery thereby enhancing business efficiency by providing diverse functionalities on-demand in a cost-effective pay-per-use manner.
#
# --------------------------------------------------------------------------------
#
# 🔹 Question 3: What are the advantages of cloud computing?
# Answer:
#  The academic study on the benefits of cloud computing identifies several critical aspects which contribute to its appeal for users and businesses alike. Firstly, accessibility is a significant advantage as applications can be treated like utilities that one may employ over the internet without needing local installation - this denotes an unparalleled convenience in application usage. Secondly, cloud computing provides tools for online development environments alongside various runtime settings through its Platform-as-a-Service (PaaS) model which empowers users to manipulate and configure applications remotely at any time of the day or night without geographical restrictions - a feature that enhances productivity immensely.
#
# In terms of cost efficiency, it is observed that cloud computing often operates on considerably lower rates compared with traditional IT approaches such as maintaining in-house servers and software licenses; this results from optimal utilization levels coupled with the elimination of overheads associated with data storage costs, maintenance fees for management among others. Furthermore, convenience extends to continuous availability alongside shared document access which allows collaborators real time viewing and editing capabilities – a feature that further augments productivity by enabling seamless collaboration across geographical boundaries without delay or difficulty in accessing vital information; the public cloud platforms even extend this service offering with additional features.
#
# Lastly, reliance on internet connectivity for access to these services underscs its cost effectiveness and efficiency as it eliminates direct interaction requirements which might otherwise be mandatory – a feature that simplifies operations tremendously by removing complexity from the user-side of interactions needed when dealing with conventional IT infrastructures.
#
# --------------------
# --------------------------------------------------------------------------------
#
# 🔹 Question 4: Explain IaaS, PaaS and SaaS models
